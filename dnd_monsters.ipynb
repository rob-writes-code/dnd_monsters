# %% [markdown]
# # DnD Monster Tracker

# %%
from kafka.admin import KafkaAdminClient, NewTopic


admin_client = KafkaAdminClient(
    bootstrap_servers="kafka:9092", 
    client_id='test'
)

topic_list = []
topic_list.append(NewTopic(name="monster_movement", num_partitions=1, replication_factor=1))
admin_client.create_topics(new_topics=topic_list, validate_only=False)

# %% [markdown]
# Create 200 events.
# The event should pick five random rows from our dnd_monsters.csv and return the monster's name and str characteristic.

# %%
import json
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType
from pyspark.sql.functions import lit, udf


spark = SparkSession.builder.appName("MonsterTracker").config("spark.jars","work/data/commons-pool2-2.11.1.jar,work/data/spark-sql-kafka-0-10_2.12-3.4.0.jar,work/data/spark-streaming-kafka-0-10-assembly_2.12-3.4.0.jar").getOrCreate()

df = spark.read.format('csv').option('header', 'true').load('./work/data/dnd_monsters.csv').where("str is not null")

# %%
# %pip install geopy

# %%
from geopy.geocoders import Nominatim   
import random
from pyspark.sql.functions import lit, udf
from datetime import datetime

def get_location_and_country():
    #get longitude and latitude
    longitude = random.randint(-180, 180)
    latitude = random.randint(-90, 90)
    
    # Create a geocoder instance for finding country from monster long&lat
    geolocator = Nominatim(user_agent="my_geocoder")
    
    # Reverse geocode to get the location information
    location = geolocator.reverse((latitude, longitude), language='en')

    # Extract the country from the location information, with a random lat and long it might not have a country
    country = "Sea"
    try:
        country = location.raw['address']['country']
    except:
        country = 'Sea'
    return [str(country), str(longitude), str(latitude)]


# location and country udf
location_udf = udf(get_location_and_country, ArrayType(StringType(), False))
longitude_udf = udf(get_location_and_country, IntegerType())
latitude_udf = udf(get_location_and_country, IntegerType())

# timestamp udf

def get_time():
    return str(datetime.now())

time_udf = udf(get_time, StringType())

# adding columns to DF
selection = df['name', 'str'].withColumn('lat', location_udf()[2]).withColumn('long', location_udf()[1]).withColumn('ts', time_udf()).withColumn('country',  location_udf()[0])

selection = selection.cache()

# %%
selection = selection.cache()

# %%
import random

x = random.randint(5, 200)
y = x - 5

selection.collect()[y:x]

# %%
import time
from pyspark.sql.functions import rand


print("starting")

# change to 200 after testing
for i in range(20):
        
    # # range for random 5
    # higher = random.randint(5, 200)
    # lower = higher - 5

    print('point 1 in loop')
    # Randomly select 5 lines
    rows_df = selection.orderBy(rand()).limit(5)
    print('point 2')

    # convert to JSON
    five_batch = rows_df.toJSON().collect()

    print("Batch DataFrame\n")
    rows_df.show()
    time.sleep(1)

    print("Batch JSON\n")
    print(five_batch)
    time.sleep(1)

    #loop through json
    for x in five_batch:
        # Write the DataFrame to Kafka
        data = [(x,),]
        write_df = spark.createDataFrame(data, ['value'])
        write_df.show(1, False)
        write_df.write.format("kafka").option("kafka.bootstrap.servers", "kafka:9092").option("topic", "monster_movement").save()
# Out:
# starting
# point 1 in loop
# point 2
# Batch DataFrame
#
# +-----------------+----+---+----+--------------------+-------+
# |             name| str|lat|long|                  ts|country|
# +-----------------+----+---+----+--------------------+-------+
# |        blink-dog|12.0| 37|  98|2023-07-21 09:50:...|  China|
# |     phase-spider|15.0| 42|  81|2023-07-21 09:52:...|  China|
# |minotaur-skeleton|18.0|-49| -88|2023-07-21 09:52:...|    Sea|
# |          mammoth|24.0|-31|-105|2023-07-21 09:52:...|    Sea|
# |              elk|16.0|-86|  57|2023-07-21 09:51:...|    Sea|
# +-----------------+----+---+----+--------------------+-------+
#
# Batch JSON
#
# ['{"name":"blink-dog","str":"12.0","lat":"37","long":"98","ts":"2023-07-21 09:50:50.747819","country":"China"}', '{"name":"phase-spider","str":"15.0","lat":"42","long":"81","ts":"2023-07-21 09:52:38.795465","country":"China"}', '{"name":"minotaur-skeleton","str":"18.0","lat":"-49","long":"-88","ts":"2023-07-21 09:52:23.750891","country":"Sea"}', '{"name":"mammoth","str":"24.0","lat":"-31","long":"-105","ts":"2023-07-21 09:52:18.256512","country":"Sea"}', '{"name":"elk","str":"16.0","lat":"-86","long":"57","ts":"2023-07-21 09:51:20.257290","country":"Sea"}']
# +------------------------------------------------------------------------------------------------------------+
# |value                                                                                                       |
# +------------------------------------------------------------------------------------------------------------+
# |{"name":"blink-dog","str":"12.0","lat":"37","long":"98","ts":"2023-07-21 09:50:50.747819","country":"China"}|
# +------------------------------------------------------------------------------------------------------------+
#
# +---------------------------------------------------------------------------------------------------------------+
# |value                                                                                                          |
# +---------------------------------------------------------------------------------------------------------------+
# |{"name":"phase-spider","str":"15.0","lat":"42","long":"81","ts":"2023-07-21 09:52:38.795465","country":"China"}|
# +---------------------------------------------------------------------------------------------------------------+
#
# +--------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                               |
# +--------------------------------------------------------------------------------------------------------------------+
# |{"name":"minotaur-skeleton","str":"18.0","lat":"-49","long":"-88","ts":"2023-07-21 09:52:23.750891","country":"Sea"}|
# +--------------------------------------------------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------------------------------------+
# |value                                                                                                      |
# +-----------------------------------------------------------------------------------------------------------+
# |{"name":"mammoth","str":"24.0","lat":"-31","long":"-105","ts":"2023-07-21 09:52:18.256512","country":"Sea"}|
# +-----------------------------------------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------------------------------+
# |value                                                                                                |
# +-----------------------------------------------------------------------------------------------------+
# |{"name":"elk","str":"16.0","lat":"-86","long":"57","ts":"2023-07-21 09:51:20.257290","country":"Sea"}|
# +-----------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +------------------+----+---+----+--------------------+-------+
# |              name| str|lat|long|                  ts|country|
# +------------------+----+---+----+--------------------+-------+
# |        umber-hulk|20.0|-37| -49|2023-07-21 09:53:...|    Sea|
# |swarm-of-rot-grubs| 2.0| 64|  85|2023-07-21 09:53:...| Russia|
# | adult-gold-dragon|27.0| 76|  37|2023-07-21 09:50:...|    Sea|
# |            drider|16.0|  3|  79|2023-07-21 09:51:...|    Sea|
# |               oni|19.0|-56|  87|2023-07-21 09:52:...|    Sea|
# +------------------+----+---+----+--------------------+-------+
#
# Batch JSON
#
# ['{"name":"umber-hulk","str":"20.0","lat":"-37","long":"-49","ts":"2023-07-21 09:53:18.295441","country":"Sea"}', '{"name":"swarm-of-rot-grubs","str":"2.0","lat":"64","long":"85","ts":"2023-07-21 09:53:12.353561","country":"Russia"}', '{"name":"adult-gold-dragon","str":"27.0","lat":"76","long":"37","ts":"2023-07-21 09:50:25.746124","country":"Sea"}', '{"name":"drider","str":"16.0","lat":"3","long":"79","ts":"2023-07-21 09:51:13.774881","country":"Sea"}', '{"name":"oni","str":"19.0","lat":"-56","long":"87","ts":"2023-07-21 09:52:33.256580","country":"Sea"}']
# +-------------------------------------------------------------------------------------------------------------+
# |value                                                                                                        |
# +-------------------------------------------------------------------------------------------------------------+
# |{"name":"umber-hulk","str":"20.0","lat":"-37","long":"-49","ts":"2023-07-21 09:53:18.295441","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------------+
#
# +---------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                                |
# +---------------------------------------------------------------------------------------------------------------------+
# |{"name":"swarm-of-rot-grubs","str":"2.0","lat":"64","long":"85","ts":"2023-07-21 09:53:12.353561","country":"Russia"}|
# +---------------------------------------------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                             |
# +------------------------------------------------------------------------------------------------------------------+
# |{"name":"adult-gold-dragon","str":"27.0","lat":"76","long":"37","ts":"2023-07-21 09:50:25.746124","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------------------------------+
# |value                                                                                                 |
# +------------------------------------------------------------------------------------------------------+
# |{"name":"drider","str":"16.0","lat":"3","long":"79","ts":"2023-07-21 09:51:13.774881","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------------------------------+
# |value                                                                                                |
# +-----------------------------------------------------------------------------------------------------+
# |{"name":"oni","str":"19.0","lat":"-56","long":"87","ts":"2023-07-21 09:52:33.256580","country":"Sea"}|
# +-----------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +----------+----+---+----+--------------------+-------+
# |      name| str|lat|long|                  ts|country|
# +----------+----+---+----+--------------------+-------+
# |      mage| 9.0| 89| -68|2023-07-21 09:52:...|    Sea|
# |     ghoul|13.0| -7| 133|2023-07-21 09:51:...|    Sea|
# |    treant|23.0|-25|  60|2023-07-21 09:53:...|    Sea|
# |clay-golem|20.0| 66|  13|2023-07-21 09:50:...| Norway|
# | hobgoblin|13.0| 47| -77|2023-07-21 09:51:...| Canada|
# +----------+----+---+----+--------------------+-------+
#
# Batch JSON
#
# ['{"name":"mage","str":"9.0","lat":"89","long":"-68","ts":"2023-07-21 09:52:16.755738","country":"Sea"}', '{"name":"ghoul","str":"13.0","lat":"-7","long":"133","ts":"2023-07-21 09:51:30.762669","country":"Sea"}', '{"name":"treant","str":"23.0","lat":"-25","long":"60","ts":"2023-07-21 09:53:14.755933","country":"Sea"}', '{"name":"clay-golem","str":"20.0","lat":"66","long":"13","ts":"2023-07-21 09:50:59.246607","country":"Norway"}', '{"name":"hobgoblin","str":"13.0","lat":"47","long":"-77","ts":"2023-07-21 09:51:59.853234","country":"Canada"}']
# +-----------------------------------------------------------------------------------------------------+
# |value                                                                                                |
# +-----------------------------------------------------------------------------------------------------+
# |{"name":"mage","str":"9.0","lat":"89","long":"-68","ts":"2023-07-21 09:52:16.755738","country":"Sea"}|
# +-----------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------------------------------------------------------------------+
# |value                                                                                                  |
# +-------------------------------------------------------------------------------------------------------+
# |{"name":"ghoul","str":"13.0","lat":"-7","long":"133","ts":"2023-07-21 09:51:30.762669","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------+
#
# +--------------------------------------------------------------------------------------------------------+
# |value                                                                                                   |
# +--------------------------------------------------------------------------------------------------------+
# |{"name":"treant","str":"23.0","lat":"-25","long":"60","ts":"2023-07-21 09:53:14.755933","country":"Sea"}|
# +--------------------------------------------------------------------------------------------------------+
#
# +--------------------------------------------------------------------------------------------------------------+
# |value                                                                                                         |
# +--------------------------------------------------------------------------------------------------------------+
# |{"name":"clay-golem","str":"20.0","lat":"66","long":"13","ts":"2023-07-21 09:50:59.246607","country":"Norway"}|
# +--------------------------------------------------------------------------------------------------------------+
#
# +--------------------------------------------------------------------------------------------------------------+
# |value                                                                                                         |
# +--------------------------------------------------------------------------------------------------------------+
# |{"name":"hobgoblin","str":"13.0","lat":"47","long":"-77","ts":"2023-07-21 09:51:59.853234","country":"Canada"}|
# +--------------------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +---------+----+---+----+--------------------+-------+
# |     name| str|lat|long|                  ts|country|
# +---------+----+---+----+--------------------+-------+
# |   lizard| 2.0| 20|  75|2023-07-21 09:52:...|  India|
# |night-hag|18.0| 20|  94|2023-07-21 09:52:...|Myanmar|
# |  cloaker|17.0|-19|-131|2023-07-21 09:50:...|    Sea|
# | archmage|10.0|-52| -36|2023-07-21 09:50:...|    Sea|
# |  banshee| 1.0| -8|  70|2023-07-21 09:50:...|    Sea|
# +---------+----+---+----+--------------------+-------+
#
# Batch JSON
#
# ['{"name":"lizard","str":"2.0","lat":"20","long":"75","ts":"2023-07-21 09:52:14.766888","country":"India"}', '{"name":"night-hag","str":"18.0","lat":"20","long":"94","ts":"2023-07-21 09:52:28.274552","country":"Myanmar"}', '{"name":"cloaker","str":"17.0","lat":"-19","long":"-131","ts":"2023-07-21 09:50:59.734098","country":"Sea"}', '{"name":"archmage","str":"10.0","lat":"-52","long":"-36","ts":"2023-07-21 09:50:37.738414","country":"Sea"}', '{"name":"banshee","str":"1.0","lat":"-8","long":"70","ts":"2023-07-21 09:50:44.282997","country":"Sea"}']
# +--------------------------------------------------------------------------------------------------------+
# |value                                                                                                   |
# +--------------------------------------------------------------------------------------------------------+
# |{"name":"lizard","str":"2.0","lat":"20","long":"75","ts":"2023-07-21 09:52:14.766888","country":"India"}|
# +--------------------------------------------------------------------------------------------------------+
#
# +--------------------------------------------------------------------------------------------------------------+
# |value                                                                                                         |
# +--------------------------------------------------------------------------------------------------------------+
# |{"name":"night-hag","str":"18.0","lat":"20","long":"94","ts":"2023-07-21 09:52:28.274552","country":"Myanmar"}|
# +--------------------------------------------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------------------------------------+
# |value                                                                                                      |
# +-----------------------------------------------------------------------------------------------------------+
# |{"name":"cloaker","str":"17.0","lat":"-19","long":"-131","ts":"2023-07-21 09:50:59.734098","country":"Sea"}|
# +-----------------------------------------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------------------------------------+
# |value                                                                                                      |
# +-----------------------------------------------------------------------------------------------------------+
# |{"name":"archmage","str":"10.0","lat":"-52","long":"-36","ts":"2023-07-21 09:50:37.738414","country":"Sea"}|
# +-----------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------------------------------------------------------------------+
# |value                                                                                                  |
# +-------------------------------------------------------------------------------------------------------+
# |{"name":"banshee","str":"1.0","lat":"-8","long":"70","ts":"2023-07-21 09:50:44.282997","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +--------------------+----+---+----+--------------------+---------+
# |                name| str|lat|long|                  ts|  country|
# +--------------------+----+---+----+--------------------+---------+
# | saber-toothed-tiger|18.0|-78| -45|2023-07-21 09:52:...|      Sea|
# |  young-black-dragon|  19|-13| 130|2023-07-21 09:53:...|Australia|
# |              zariel|  27| 51| -73|2023-07-21 09:53:...|   Canada|
# |            glabrezu|20.0| 82|-179|2023-07-21 09:51:...|      Sea|
# |ancient-green-dragon|27.0|  3|-174|2023-07-21 09:50:...|      Sea|
# +--------------------+----+---+----+--------------------+---------+
#
# Batch JSON
#
# ['{"name":"saber-toothed-tiger","str":"18.0","lat":"-78","long":"-45","ts":"2023-07-21 09:52:53.310764","country":"Sea"}', '{"name":"young-black-dragon","str":"19","lat":"-13","long":"130","ts":"2023-07-21 09:53:34.373667","country":"Australia"}', '{"name":"zariel","str":"27","lat":"51","long":"-73","ts":"2023-07-21 09:53:41.312539","country":"Canada"}', '{"name":"glabrezu","str":"20.0","lat":"82","long":"-179","ts":"2023-07-21 09:51:46.255575","country":"Sea"}', '{"name":"ancient-green-dragon","str":"27.0","lat":"3","long":"-174","ts":"2023-07-21 09:50:32.235796","country":"Sea"}']
# +----------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                                 |
# +----------------------------------------------------------------------------------------------------------------------+
# |{"name":"saber-toothed-tiger","str":"18.0","lat":"-78","long":"-45","ts":"2023-07-21 09:52:53.310764","country":"Sea"}|
# +----------------------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                                    |
# +-------------------------------------------------------------------------------------------------------------------------+
# |{"name":"young-black-dragon","str":"19","lat":"-13","long":"130","ts":"2023-07-21 09:53:34.373667","country":"Australia"}|
# +-------------------------------------------------------------------------------------------------------------------------+
#
# +---------------------------------------------------------------------------------------------------------+
# |value                                                                                                    |
# +---------------------------------------------------------------------------------------------------------+
# |{"name":"zariel","str":"27","lat":"51","long":"-73","ts":"2023-07-21 09:53:41.312539","country":"Canada"}|
# +---------------------------------------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------------------------------------+
# |value                                                                                                      |
# +-----------------------------------------------------------------------------------------------------------+
# |{"name":"glabrezu","str":"20.0","lat":"82","long":"-179","ts":"2023-07-21 09:51:46.255575","country":"Sea"}|
# +-----------------------------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                                 |
# +----------------------------------------------------------------------------------------------------------------------+
# |{"name":"ancient-green-dragon","str":"27.0","lat":"3","long":"-174","ts":"2023-07-21 09:50:32.235796","country":"Sea"}|
# +----------------------------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +------------------+----+---+----+--------------------+-------+
# |              name| str|lat|long|                  ts|country|
# +------------------+----+---+----+--------------------+-------+
# |drow-house-captain|14.0|-87|  95|2023-07-21 09:51:...|    Sea|
# | lizardfolk-shaman|15.0|-53|  29|2023-07-21 09:52:...|    Sea|
# |              boar|13.0| 12|-129|2023-07-21 09:50:...|    Sea|
# |            zombie|  13| 29| -57|2023-07-21 09:53:...|    Sea|
# |               dao|23.0|-90|   6|2023-07-21 09:51:...|    Sea|
# +------------------+----+---+----+--------------------+-------+
#
# Batch JSON
#
# ['{"name":"drow-house-captain","str":"14.0","lat":"-87","long":"95","ts":"2023-07-21 09:51:14.738422","country":"Sea"}', '{"name":"lizardfolk-shaman","str":"15.0","lat":"-53","long":"29","ts":"2023-07-21 09:52:16.297812","country":"Sea"}', '{"name":"boar","str":"13.0","lat":"12","long":"-129","ts":"2023-07-21 09:50:52.268124","country":"Sea"}', '{"name":"zombie","str":"13","lat":"29","long":"-57","ts":"2023-07-21 09:53:41.850098","country":"Sea"}', '{"name":"dao","str":"23.0","lat":"-90","long":"6","ts":"2023-07-21 09:51:06.733677","country":"Sea"}']
# +--------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                               |
# +--------------------------------------------------------------------------------------------------------------------+
# |{"name":"drow-house-captain","str":"14.0","lat":"-87","long":"95","ts":"2023-07-21 09:51:14.738422","country":"Sea"}|
# +--------------------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                              |
# +-------------------------------------------------------------------------------------------------------------------+
# |{"name":"lizardfolk-shaman","str":"15.0","lat":"-53","long":"29","ts":"2023-07-21 09:52:16.297812","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------------------------------------------------------------------+
# |value                                                                                                  |
# +-------------------------------------------------------------------------------------------------------+
# |{"name":"boar","str":"13.0","lat":"12","long":"-129","ts":"2023-07-21 09:50:52.268124","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------------------------------+
# |value                                                                                                 |
# +------------------------------------------------------------------------------------------------------+
# |{"name":"zombie","str":"13","lat":"29","long":"-57","ts":"2023-07-21 09:53:41.850098","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------------------+
# |value                                                                                               |
# +----------------------------------------------------------------------------------------------------+
# |{"name":"dao","str":"23.0","lat":"-90","long":"6","ts":"2023-07-21 09:51:06.733677","country":"Sea"}|
# +----------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +-----------------+----+---+----+--------------------+-------+
# |             name| str|lat|long|                  ts|country|
# +-----------------+----+---+----+--------------------+-------+
# |mummified-warrior|13.0|-61|  -3|2023-07-21 09:52:...|    Sea|
# |          vampire|18.0|-78| 111|2023-07-21 09:53:...|    Sea|
# |             azer|17.0| 32| 158|2023-07-21 09:50:...|    Sea|
# |       darkmantle|16.0| 18|  11|2023-07-21 09:51:...|  Niger|
# |             lich|11.0|-41| 158|2023-07-21 09:52:...|    Sea|
# +-----------------+----+---+----+--------------------+-------+
#
# Batch JSON
#
# ['{"name":"mummified-warrior","str":"13.0","lat":"-61","long":"-3","ts":"2023-07-21 09:52:25.865987","country":"Sea"}', '{"name":"vampire","str":"18.0","lat":"-78","long":"111","ts":"2023-07-21 09:53:19.255560","country":"Sea"}', '{"name":"azer","str":"17.0","lat":"32","long":"158","ts":"2023-07-21 09:50:41.240900","country":"Sea"}', '{"name":"darkmantle","str":"16.0","lat":"18","long":"11","ts":"2023-07-21 09:51:07.241483","country":"Niger"}', '{"name":"lich","str":"11.0","lat":"-41","long":"158","ts":"2023-07-21 09:52:13.782243","country":"Sea"}']
# +-------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                              |
# +-------------------------------------------------------------------------------------------------------------------+
# |{"name":"mummified-warrior","str":"13.0","lat":"-61","long":"-3","ts":"2023-07-21 09:52:25.865987","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------------------------+
# |value                                                                                                     |
# +----------------------------------------------------------------------------------------------------------+
# |{"name":"vampire","str":"18.0","lat":"-78","long":"111","ts":"2023-07-21 09:53:19.255560","country":"Sea"}|
# +----------------------------------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------------------------------+
# |value                                                                                                 |
# +------------------------------------------------------------------------------------------------------+
# |{"name":"azer","str":"17.0","lat":"32","long":"158","ts":"2023-07-21 09:50:41.240900","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------------------------------------------------------------------------+
# |value                                                                                                        |
# +-------------------------------------------------------------------------------------------------------------+
# |{"name":"darkmantle","str":"16.0","lat":"18","long":"11","ts":"2023-07-21 09:51:07.241483","country":"Niger"}|
# +-------------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------------------------------------------------------------------+
# |value                                                                                                  |
# +-------------------------------------------------------------------------------------------------------+
# |{"name":"lich","str":"11.0","lat":"-41","long":"158","ts":"2023-07-21 09:52:13.782243","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +-----------------+----+---+----+--------------------+-------+
# |             name| str|lat|long|                  ts|country|
# +-----------------+----+---+----+--------------------+-------+
# |           couatl|16.0| 48|  41|2023-07-21 09:51:...| Russia|
# |          banshee| 1.0| -8|  70|2023-07-21 09:50:...|    Sea|
# |constrictor-snake|15.0| 76| 132|2023-07-21 09:51:...|    Sea|
# |laeral-silverhand|13.0|-30|-144|2023-07-21 09:52:...|    Sea|
# |      cloud-giant|27.0|-16|  44|2023-07-21 09:51:...|    Sea|
# +-----------------+----+---+----+--------------------+-------+
#
# Batch JSON
#
# ['{"name":"couatl","str":"16.0","lat":"48","long":"41","ts":"2023-07-21 09:51:02.767201","country":"Russia"}', '{"name":"banshee","str":"1.0","lat":"-8","long":"70","ts":"2023-07-21 09:50:44.282997","country":"Sea"}', '{"name":"constrictor-snake","str":"15.0","lat":"76","long":"132","ts":"2023-07-21 09:51:01.743529","country":"Sea"}', '{"name":"laeral-silverhand","str":"13.0","lat":"-30","long":"-144","ts":"2023-07-21 09:52:12.345126","country":"Sea"}', '{"name":"cloud-giant","str":"27.0","lat":"-16","long":"44","ts":"2023-07-21 09:51:00.241916","country":"Sea"}']
# +----------------------------------------------------------------------------------------------------------+
# |value                                                                                                     |
# +----------------------------------------------------------------------------------------------------------+
# |{"name":"couatl","str":"16.0","lat":"48","long":"41","ts":"2023-07-21 09:51:02.767201","country":"Russia"}|
# +----------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------------------------------------------------------------------+
# |value                                                                                                  |
# +-------------------------------------------------------------------------------------------------------+
# |{"name":"banshee","str":"1.0","lat":"-8","long":"70","ts":"2023-07-21 09:50:44.282997","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                              |
# +-------------------------------------------------------------------------------------------------------------------+
# |{"name":"constrictor-snake","str":"15.0","lat":"76","long":"132","ts":"2023-07-21 09:51:01.743529","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------------------+
#
# +---------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                                |
# +---------------------------------------------------------------------------------------------------------------------+
# |{"name":"laeral-silverhand","str":"13.0","lat":"-30","long":"-144","ts":"2023-07-21 09:52:12.345126","country":"Sea"}|
# +---------------------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------------------------------------------------------------------------+
# |value                                                                                                        |
# +-------------------------------------------------------------------------------------------------------------+
# |{"name":"cloud-giant","str":"27.0","lat":"-16","long":"44","ts":"2023-07-21 09:51:00.241916","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +------------+----+---+----+--------------------+---------+
# |        name| str|lat|long|                  ts|  country|
# +------------+----+---+----+--------------------+---------+
# |   aarakocra|10.0|-60| -34|2023-07-21 09:50:...|      Sea|
# |       scout|11.0|-20| 149|2023-07-21 09:52:...|Australia|
# |killer-whale|19.0|-50|  23|2023-07-21 09:52:...|      Sea|
# |  giant-boar|17.0|-89|  54|2023-07-21 09:51:...|      Sea|
# |      badger| 4.0| 24|-128|2023-07-21 09:50:...|      Sea|
# +------------+----+---+----+--------------------+---------+
#
# Batch JSON
#
# ['{"name":"aarakocra","str":"10.0","lat":"-60","long":"-34","ts":"2023-07-21 09:50:21.734794","country":"Sea"}', '{"name":"scout","str":"11.0","lat":"-20","long":"149","ts":"2023-07-21 09:52:55.870532","country":"Australia"}', '{"name":"killer-whale","str":"19.0","lat":"-50","long":"23","ts":"2023-07-21 09:52:08.252467","country":"Sea"}', '{"name":"giant-boar","str":"17.0","lat":"-89","long":"54","ts":"2023-07-21 09:51:32.756131","country":"Sea"}', '{"name":"badger","str":"4.0","lat":"24","long":"-128","ts":"2023-07-21 09:50:42.321637","country":"Sea"}']
# +------------------------------------------------------------------------------------------------------------+
# |value                                                                                                       |
# +------------------------------------------------------------------------------------------------------------+
# |{"name":"aarakocra","str":"10.0","lat":"-60","long":"-34","ts":"2023-07-21 09:50:21.734794","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------------+
#
# +--------------------------------------------------------------------------------------------------------------+
# |value                                                                                                         |
# +--------------------------------------------------------------------------------------------------------------+
# |{"name":"scout","str":"11.0","lat":"-20","long":"149","ts":"2023-07-21 09:52:55.870532","country":"Australia"}|
# +--------------------------------------------------------------------------------------------------------------+
#
# +--------------------------------------------------------------------------------------------------------------+
# |value                                                                                                         |
# +--------------------------------------------------------------------------------------------------------------+
# |{"name":"killer-whale","str":"19.0","lat":"-50","long":"23","ts":"2023-07-21 09:52:08.252467","country":"Sea"}|
# +--------------------------------------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------------------------------------+
# |value                                                                                                       |
# +------------------------------------------------------------------------------------------------------------+
# |{"name":"giant-boar","str":"17.0","lat":"-89","long":"54","ts":"2023-07-21 09:51:32.756131","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------------+
#
# +--------------------------------------------------------------------------------------------------------+
# |value                                                                                                   |
# +--------------------------------------------------------------------------------------------------------+
# |{"name":"badger","str":"4.0","lat":"24","long":"-128","ts":"2023-07-21 09:50:42.321637","country":"Sea"}|
# +--------------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +-----------+----+---+----+--------------------+-------+
# |       name| str|lat|long|                  ts|country|
# +-----------+----+---+----+--------------------+-------+
# |       deer|11.0| 31| 119|2023-07-21 09:51:...|  China|
# |     lemure|10.0| 84|   1|2023-07-21 09:52:...|    Sea|
# |       ogre|19.0| 80|-118|2023-07-21 09:52:...|    Sea|
# |draft-horse|18.0| 18|-128|2023-07-21 09:51:...|    Sea|
# |dust-mephit| 5.0|-71|  65|2023-07-21 09:51:...|    Sea|
# +-----------+----+---+----+--------------------+-------+
#
# Batch JSON
#
# ['{"name":"deer","str":"11.0","lat":"31","long":"119","ts":"2023-07-21 09:51:08.798117","country":"China"}', '{"name":"lemure","str":"10.0","lat":"84","long":"1","ts":"2023-07-21 09:52:13.257723","country":"Sea"}', '{"name":"ogre","str":"19.0","lat":"80","long":"-118","ts":"2023-07-21 09:52:32.258682","country":"Sea"}', '{"name":"draft-horse","str":"18.0","lat":"18","long":"-128","ts":"2023-07-21 09:51:12.239075","country":"Sea"}', '{"name":"dust-mephit","str":"5.0","lat":"-71","long":"65","ts":"2023-07-21 09:51:17.769614","country":"Sea"}']
# +--------------------------------------------------------------------------------------------------------+
# |value                                                                                                   |
# +--------------------------------------------------------------------------------------------------------+
# |{"name":"deer","str":"11.0","lat":"31","long":"119","ts":"2023-07-21 09:51:08.798117","country":"China"}|
# +--------------------------------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------------------------------+
# |value                                                                                                 |
# +------------------------------------------------------------------------------------------------------+
# |{"name":"lemure","str":"10.0","lat":"84","long":"1","ts":"2023-07-21 09:52:13.257723","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------------------------------------------------------------------+
# |value                                                                                                  |
# +-------------------------------------------------------------------------------------------------------+
# |{"name":"ogre","str":"19.0","lat":"80","long":"-118","ts":"2023-07-21 09:52:32.258682","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------+
#
# +--------------------------------------------------------------------------------------------------------------+
# |value                                                                                                         |
# +--------------------------------------------------------------------------------------------------------------+
# |{"name":"draft-horse","str":"18.0","lat":"18","long":"-128","ts":"2023-07-21 09:51:12.239075","country":"Sea"}|
# +--------------------------------------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------------------------------------+
# |value                                                                                                       |
# +------------------------------------------------------------------------------------------------------------+
# |{"name":"dust-mephit","str":"5.0","lat":"-71","long":"65","ts":"2023-07-21 09:51:17.769614","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +------------------+----+---+----+--------------------+-------+
# |              name| str|lat|long|                  ts|country|
# +------------------+----+---+----+--------------------+-------+
# |      horned-devil|22.0| 28| 142|2023-07-21 09:52:...|    Sea|
# |      flying-snake| 4.0|-90|-135|2023-07-21 09:51:...|    Sea|
# |         ice-devil|21.0|-88| 163|2023-07-21 09:52:...|    Sea|
# |orc-eye-of-gruumsh|16.0| 15|  74|2023-07-21 09:52:...|  India|
# |            bandit|11.0| -3| -88|2023-07-21 09:50:...|    Sea|
# +------------------+----+---+----+--------------------+-------+
#
# Batch JSON
#
# ['{"name":"horned-devil","str":"22.0","lat":"28","long":"142","ts":"2023-07-21 09:52:02.255186","country":"Sea"}', '{"name":"flying-snake","str":"4.0","lat":"-90","long":"-135","ts":"2023-07-21 09:51:25.343950","country":"Sea"}', '{"name":"ice-devil","str":"21.0","lat":"-88","long":"163","ts":"2023-07-21 09:52:04.256000","country":"Sea"}', '{"name":"orc-eye-of-gruumsh","str":"16.0","lat":"15","long":"74","ts":"2023-07-21 09:52:34.265408","country":"India"}', '{"name":"bandit","str":"11.0","lat":"-3","long":"-88","ts":"2023-07-21 09:50:43.240629","country":"Sea"}']
# +--------------------------------------------------------------------------------------------------------------+
# |value                                                                                                         |
# +--------------------------------------------------------------------------------------------------------------+
# |{"name":"horned-devil","str":"22.0","lat":"28","long":"142","ts":"2023-07-21 09:52:02.255186","country":"Sea"}|
# +--------------------------------------------------------------------------------------------------------------+
#
# +---------------------------------------------------------------------------------------------------------------+
# |value                                                                                                          |
# +---------------------------------------------------------------------------------------------------------------+
# |{"name":"flying-snake","str":"4.0","lat":"-90","long":"-135","ts":"2023-07-21 09:51:25.343950","country":"Sea"}|
# +---------------------------------------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------------------------------------+
# |value                                                                                                       |
# +------------------------------------------------------------------------------------------------------------+
# |{"name":"ice-devil","str":"21.0","lat":"-88","long":"163","ts":"2023-07-21 09:52:04.256000","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------------+
#
# +---------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                                |
# +---------------------------------------------------------------------------------------------------------------------+
# |{"name":"orc-eye-of-gruumsh","str":"16.0","lat":"15","long":"74","ts":"2023-07-21 09:52:34.265408","country":"India"}|
# +---------------------------------------------------------------------------------------------------------------------+
#
# +--------------------------------------------------------------------------------------------------------+
# |value                                                                                                   |
# +--------------------------------------------------------------------------------------------------------+
# |{"name":"bandit","str":"11.0","lat":"-3","long":"-88","ts":"2023-07-21 09:50:43.240629","country":"Sea"}|
# +--------------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +--------------+----+---+----+--------------------+-------+
# |          name| str|lat|long|                  ts|country|
# +--------------+----+---+----+--------------------+-------+
# |           elk|16.0|-86|  57|2023-07-21 09:51:...|    Sea|
# |           owl| 3.0|-20| -84|2023-07-21 09:52:...|    Sea|
# |       chimera|19.0| 30| -48|2023-07-21 09:50:...|    Sea|
# |wild-dog-alpha|  17| 46| 132|2023-07-21 09:53:...|  China|
# |    mud-mephit| 8.0|-19|  83|2023-07-21 09:52:...|    Sea|
# +--------------+----+---+----+--------------------+-------+
#
# Batch JSON
#
# ['{"name":"elk","str":"16.0","lat":"-86","long":"57","ts":"2023-07-21 09:51:20.257290","country":"Sea"}', '{"name":"owl","str":"3.0","lat":"-20","long":"-84","ts":"2023-07-21 09:52:36.311141","country":"Sea"}', '{"name":"chimera","str":"19.0","lat":"30","long":"-48","ts":"2023-07-21 09:50:58.237723","country":"Sea"}', '{"name":"wild-dog-alpha","str":"17","lat":"46","long":"132","ts":"2023-07-21 09:53:29.272671","country":"China"}', '{"name":"mud-mephit","str":"8.0","lat":"-19","long":"83","ts":"2023-07-21 09:52:24.756371","country":"Sea"}']
# +-----------------------------------------------------------------------------------------------------+
# |value                                                                                                |
# +-----------------------------------------------------------------------------------------------------+
# |{"name":"elk","str":"16.0","lat":"-86","long":"57","ts":"2023-07-21 09:51:20.257290","country":"Sea"}|
# +-----------------------------------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------------------------------+
# |value                                                                                                |
# +-----------------------------------------------------------------------------------------------------+
# |{"name":"owl","str":"3.0","lat":"-20","long":"-84","ts":"2023-07-21 09:52:36.311141","country":"Sea"}|
# +-----------------------------------------------------------------------------------------------------+
#
# +---------------------------------------------------------------------------------------------------------+
# |value                                                                                                    |
# +---------------------------------------------------------------------------------------------------------+
# |{"name":"chimera","str":"19.0","lat":"30","long":"-48","ts":"2023-07-21 09:50:58.237723","country":"Sea"}|
# +---------------------------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------------------------------+
# |value                                                                                                           |
# +----------------------------------------------------------------------------------------------------------------+
# |{"name":"wild-dog-alpha","str":"17","lat":"46","long":"132","ts":"2023-07-21 09:53:29.272671","country":"China"}|
# +----------------------------------------------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------------------------------------+
# |value                                                                                                      |
# +-----------------------------------------------------------------------------------------------------------+
# |{"name":"mud-mephit","str":"8.0","lat":"-19","long":"83","ts":"2023-07-21 09:52:24.756371","country":"Sea"}|
# +-----------------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +---------+----+---+----+--------------------+----------+
# |     name| str|lat|long|                  ts|   country|
# +---------+----+---+----+--------------------+----------+
# |weretiger|17.0|-16|  32|2023-07-21 09:53:...|Mozambique|
# |  wererat|10.0|-10|-135|2023-07-21 09:53:...|       Sea|
# |    gauth|10.0|-85|  80|2023-07-21 09:51:...|       Sea|
# | succubus| 8.0|-41|  70|2023-07-21 09:53:...|       Sea|
# | revenant|18.0| 33| 129|2023-07-21 09:52:...|     Japan|
# +---------+----+---+----+--------------------+----------+
#
# Batch JSON
#
# ...
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +--------------+----+---+----+--------------------+-------+
# |          name| str|lat|long|                  ts|country|
# +--------------+----+---+----+--------------------+-------+
# |         ghost| 7.0| 38| -44|2023-07-21 09:51:...|    Sea|
# |    hippogriff|17.0|-29| 170|2023-07-21 09:51:...|    Sea|
# |      rakshasa|14.0|-54|-138|2023-07-21 09:52:...|    Sea|
# |   giant-shark|23.0|-65|-116|2023-07-21 09:51:...|    Sea|
# |ancient-shadow| 6.0|-66| 125|2023-07-21 09:50:...|    Sea|
# +--------------+----+---+----+--------------------+-------+
#
# Batch JSON
#
# ['{"name":"ghost","str":"7.0","lat":"38","long":"-44","ts":"2023-07-21 09:51:30.259091","country":"Sea"}', '{"name":"hippogriff","str":"17.0","lat":"-29","long":"170","ts":"2023-07-21 09:51:59.257501","country":"Sea"}', '{"name":"rakshasa","str":"14.0","lat":"-54","long":"-138","ts":"2023-07-21 09:52:46.257044","country":"Sea"}', '{"name":"giant-shark","str":"23.0","lat":"-65","long":"-116","ts":"2023-07-21 09:51:41.832257","country":"Sea"}', '{"name":"ancient-shadow","str":"6.0","lat":"-66","long":"125","ts":"2023-07-21 09:50:33.236858","country":"Sea"}']
# +------------------------------------------------------------------------------------------------------+
# |value                                                                                                 |
# +------------------------------------------------------------------------------------------------------+
# |{"name":"ghost","str":"7.0","lat":"38","long":"-44","ts":"2023-07-21 09:51:30.259091","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------------------------------------------------------------------------+
# |value                                                                                                        |
# +-------------------------------------------------------------------------------------------------------------+
# |{"name":"hippogriff","str":"17.0","lat":"-29","long":"170","ts":"2023-07-21 09:51:59.257501","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------------------------------------+
# |value                                                                                                       |
# +------------------------------------------------------------------------------------------------------------+
# |{"name":"rakshasa","str":"14.0","lat":"-54","long":"-138","ts":"2023-07-21 09:52:46.257044","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------------+
#
# +---------------------------------------------------------------------------------------------------------------+
# |value                                                                                                          |
# +---------------------------------------------------------------------------------------------------------------+
# |{"name":"giant-shark","str":"23.0","lat":"-65","long":"-116","ts":"2023-07-21 09:51:41.832257","country":"Sea"}|
# +---------------------------------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------------------------------+
# |value                                                                                                           |
# +----------------------------------------------------------------------------------------------------------------+
# |{"name":"ancient-shadow","str":"6.0","lat":"-66","long":"125","ts":"2023-07-21 09:50:33.236858","country":"Sea"}|
# +----------------------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +------------+----+---+----+--------------------+---------+
# |        name| str|lat|long|                  ts|  country|
# +------------+----+---+----+--------------------+---------+
# |   hobgoblin|13.0| 47| -77|2023-07-21 09:51:...|   Canada|
# |  rhinoceros|21.0|-30|  75|2023-07-21 09:52:...|      Sea|
# |        hawk| 5.0|-21| 152|2023-07-21 09:51:...|Australia|
# |flying-sword|12.0|-51|  37|2023-07-21 09:51:...|      Sea|
# |    planetar|24.0|-77|  87|2023-07-21 09:52:...|      Sea|
# +------------+----+---+----+--------------------+---------+
#
# Batch JSON
#
# ['{"name":"hobgoblin","str":"13.0","lat":"47","long":"-77","ts":"2023-07-21 09:51:59.853234","country":"Canada"}', '{"name":"rhinoceros","str":"21.0","lat":"-30","long":"75","ts":"2023-07-21 09:52:50.256771","country":"Sea"}', '{"name":"hawk","str":"5.0","lat":"-21","long":"152","ts":"2023-07-21 09:51:56.773422","country":"Australia"}', '{"name":"flying-sword","str":"12.0","lat":"-51","long":"37","ts":"2023-07-21 09:51:25.857880","country":"Sea"}', '{"name":"planetar","str":"24.0","lat":"-77","long":"87","ts":"2023-07-21 09:52:40.267954","country":"Sea"}']
# +--------------------------------------------------------------------------------------------------------------+
# |value                                                                                                         |
# +--------------------------------------------------------------------------------------------------------------+
# |{"name":"hobgoblin","str":"13.0","lat":"47","long":"-77","ts":"2023-07-21 09:51:59.853234","country":"Canada"}|
# +--------------------------------------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------------------------------------+
# |value                                                                                                       |
# +------------------------------------------------------------------------------------------------------------+
# |{"name":"rhinoceros","str":"21.0","lat":"-30","long":"75","ts":"2023-07-21 09:52:50.256771","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------------------------------------+
# |value                                                                                                       |
# +------------------------------------------------------------------------------------------------------------+
# |{"name":"hawk","str":"5.0","lat":"-21","long":"152","ts":"2023-07-21 09:51:56.773422","country":"Australia"}|
# +------------------------------------------------------------------------------------------------------------+
#
# +--------------------------------------------------------------------------------------------------------------+
# |value                                                                                                         |
# +--------------------------------------------------------------------------------------------------------------+
# |{"name":"flying-sword","str":"12.0","lat":"-51","long":"37","ts":"2023-07-21 09:51:25.857880","country":"Sea"}|
# +--------------------------------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------------------------+
# |value                                                                                                     |
# +----------------------------------------------------------------------------------------------------------+
# |{"name":"planetar","str":"24.0","lat":"-77","long":"87","ts":"2023-07-21 09:52:40.267954","country":"Sea"}|
# +----------------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +----------------+----+---+----+--------------------+--------+
# |            name| str|lat|long|                  ts| country|
# +----------------+----+---+----+--------------------+--------+
# |       gray-ooze|12.0| 49| -14|2023-07-21 09:51:...|     Sea|
# |venerable-shadow| 6.0| 65|-140|2023-07-21 09:53:...|  Canada|
# | giant-crocodile|21.0| 76|  27|2023-07-21 09:51:...|     Sea|
# |           camel|16.0|-74|  34|2023-07-21 09:50:...|     Sea|
# |       tarrasque|30.0|  6| 102|2023-07-21 09:53:...|Malaysia|
# +----------------+----+---+----+--------------------+--------+
#
# Batch JSON
#
# ['{"name":"gray-ooze","str":"12.0","lat":"49","long":"-14","ts":"2023-07-21 09:51:50.257227","country":"Sea"}', '{"name":"venerable-shadow","str":"6.0","lat":"65","long":"-140","ts":"2023-07-21 09:53:20.257739","country":"Canada"}', '{"name":"giant-crocodile","str":"21.0","lat":"76","long":"27","ts":"2023-07-21 09:51:34.756254","country":"Sea"}', '{"name":"camel","str":"16.0","lat":"-74","long":"34","ts":"2023-07-21 09:50:56.264076","country":"Sea"}', '{"name":"tarrasque","str":"30.0","lat":"6","long":"102","ts":"2023-07-21 09:53:13.272444","country":"Malaysia"}']
# +-----------------------------------------------------------------------------------------------------------+
# |value                                                                                                      |
# +-----------------------------------------------------------------------------------------------------------+
# |{"name":"gray-ooze","str":"12.0","lat":"49","long":"-14","ts":"2023-07-21 09:51:50.257227","country":"Sea"}|
# +-----------------------------------------------------------------------------------------------------------+
#
# +---------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                                |
# +---------------------------------------------------------------------------------------------------------------------+
# |{"name":"venerable-shadow","str":"6.0","lat":"65","long":"-140","ts":"2023-07-21 09:53:20.257739","country":"Canada"}|
# +---------------------------------------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------------------------------+
# |value                                                                                                           |
# +----------------------------------------------------------------------------------------------------------------+
# |{"name":"giant-crocodile","str":"21.0","lat":"76","long":"27","ts":"2023-07-21 09:51:34.756254","country":"Sea"}|
# +----------------------------------------------------------------------------------------------------------------+
#
# +-------------------------------------------------------------------------------------------------------+
# |value                                                                                                  |
# +-------------------------------------------------------------------------------------------------------+
# |{"name":"camel","str":"16.0","lat":"-74","long":"34","ts":"2023-07-21 09:50:56.264076","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------+
#
# +---------------------------------------------------------------------------------------------------------------+
# |value                                                                                                          |
# +---------------------------------------------------------------------------------------------------------------+
# |{"name":"tarrasque","str":"30.0","lat":"6","long":"102","ts":"2023-07-21 09:53:13.272444","country":"Malaysia"}|
# +---------------------------------------------------------------------------------------------------------------+
#
# point 1 in loop
# point 2
# Batch DataFrame
#
# +--------------------+----+---+----+--------------------+-------+
# |                name| str|lat|long|                  ts|country|
# +--------------------+----+---+----+--------------------+-------+
# |   adult-blue-dragon|25.0| 42| 179|2023-07-21 09:50:...|    Sea|
# |                 elk|16.0|-86|  57|2023-07-21 09:51:...|    Sea|
# |              wraith|   6|-86| 167|2023-07-21 09:53:...|    Sea|
# |ancient-brass-dragon|27.0|-35|-128|2023-07-21 09:50:...|    Sea|
# |        hunter-shark|18.0|-36|-143|2023-07-21 09:52:...|    Sea|
# +--------------------+----+---+----+--------------------+-------+
#
# Batch JSON
#
# ['{"name":"adult-blue-dragon","str":"25.0","lat":"42","long":"179","ts":"2023-07-21 09:50:23.738392","country":"Sea"}', '{"name":"elk","str":"16.0","lat":"-86","long":"57","ts":"2023-07-21 09:51:20.257290","country":"Sea"}', '{"name":"wraith","str":"6","lat":"-86","long":"167","ts":"2023-07-21 09:53:32.256607","country":"Sea"}', '{"name":"ancient-brass-dragon","str":"27.0","lat":"-35","long":"-128","ts":"2023-07-21 09:50:30.238700","country":"Sea"}', '{"name":"hunter-shark","str":"18.0","lat":"-36","long":"-143","ts":"2023-07-21 09:52:02.824410","country":"Sea"}']
# +-------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                              |
# +-------------------------------------------------------------------------------------------------------------------+
# |{"name":"adult-blue-dragon","str":"25.0","lat":"42","long":"179","ts":"2023-07-21 09:50:23.738392","country":"Sea"}|
# +-------------------------------------------------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------------------------------+
# |value                                                                                                |
# +-----------------------------------------------------------------------------------------------------+
# |{"name":"elk","str":"16.0","lat":"-86","long":"57","ts":"2023-07-21 09:51:20.257290","country":"Sea"}|
# +-----------------------------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------------------------------+
# |value                                                                                                 |
# +------------------------------------------------------------------------------------------------------+
# |{"name":"wraith","str":"6","lat":"-86","long":"167","ts":"2023-07-21 09:53:32.256607","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                                   |
# +------------------------------------------------------------------------------------------------------------------------+
# |{"name":"ancient-brass-dragon","str":"27.0","lat":"-35","long":"-128","ts":"2023-07-21 09:50:30.238700","country":"Sea"}|
# +------------------------------------------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------------------------------+
# |value                                                                                                           |
# +----------------------------------------------------------------------------------------------------------------+
# |{"name":"hunter-shark","str":"18.0","lat":"-36","long":"-143","ts":"2023-07-21 09:52:02.824410","country":"Sea"}|
# +----------------------------------------------------------------------------------------------------------------+

# %%
# %pip install geonamescache

# %% [markdown]
# * Create a field called population, if the country doesn't return the word "sea", as in the monster is at sea and no population.
# * Create a field called damage, if the population is greater than 1 then divide the population by 1000 and multple that by the str of the monster. Otherwise just return their str.
# * Create one stream to console that shows the name of the country and how much damage it has taken.
# * Create another stream that shows a dataset with the monsters and how much damage they have caused.

# %%
from geonamescache import GeonamesCache

def get_country_population(country_name):
    geonames = GeonamesCache()
    population = 0
    if country_name != 'Sea':
        country_data = geonames.get_countries_by_names().get(country_name)
        # create populaton
        population = country_data.get('population')
    else:
        print(f'country not found, likely ocean: {country_name}, population likely 0.')
    return population

population_udf = udf(get_country_population, IntegerType())

print(selection['Country'])

# adding columns to DF
selection = selection.withColumn('Population', population_udf(selection['Country']))

selection = selection.cache()

selection.show()

# %%
from geonamescache import GeonamesCache
from pyspark.sql.functions import col, when
from pyspark.sql.functions import sum as _sum

def get_country_population(country_name):
    geonames = GeonamesCache()
    # population = 1
    try:
        if country_name != 'Sea':
            country_data = geonames.get_countries_by_names().get(country_name)
            population = country_data.get('population')
    except:
        population = 1
        print("{} country not found".format(population))
    return population

# Example usage


from pyspark.sql.functions import udf

from pyspark.sql.types import StructType, StringType, IntegerType
from pyspark.sql.functions import from_json
from pyspark.sql import SparkSession
from pyspark.streaming import StreamingContext
from pyspark.sql.types import DecimalType

spark = SparkSession.builder.appName("Monsters").config("spark.jars","commons-pool2-2.11.1.jar,spark-sql-kafka-0-10_2.12-3.4.0.jar,spark-streaming-kafka-0-10-assembly_2.12-3.4.0.jar").getOrCreate()
get_country_population_udf = udf(get_country_population, IntegerType())

schema = StructType() \
    .add("name", StringType()) \
    .add("str", StringType()) \
    .add("ts", StringType()) \
    .add("lat", StringType()) \
    .add("long", StringType()) \
    .add("country", StringType()) \

df = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "kafka:9092") \
    .option("subscribe", "monster_movement") \
    .option("kafka.group.id", "tester") \
    .option("startingOffsets", "earliest") \
    .option("maxOffsetsPerTrigger", 1) \
    .load() \
    .selectExpr("CAST(value AS STRING)")

# Parse the JSON data and apply the schema
df = df.select(from_json(df.value, schema).alias("data")).select("data.*")

withPopulation = df.withColumn("population", get_country_population_udf(df["country"]))
withDamage = withPopulation.withColumn("damage", when(col("population") > 1, (withPopulation['population'] / 1000) * withPopulation['str']).otherwise(withPopulation['str']))
strongest_monster = withDamage.groupBy("name").agg(_sum(col("damage").cast(DecimalType())).alias("monster_damage"))
worst_country = withDamage.groupBy("country").agg(_sum(col("damage").cast(DecimalType())).alias("country_damage"))

query = worst_country \
    .writeStream \
    .outputMode("complete") \
    .format("console") \
    .start() \


query2 = strongest_monster \
    .writeStream \
    .outputMode("complete") \
    .format("console") \
    .start() \

query.awaitTermination()
query2.awaitTermination()
# Out:
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 70
#      57 query = worst_country \
#      58     .writeStream \
#      59     .outputMode("complete") \
#      60     .format("console") \
#      61     .start() \
#      64 query2 = strongest_monster \
#      65     .writeStream \
#      66     .outputMode("complete") \
#      67     .format("console") \
#      68     .start() \
# ---> 70 query.awaitTermination()
#      71 query2.awaitTermination()
#
# File /usr/local/spark/python/pyspark/sql/streaming/query.py:201, in StreamingQuery.awaitTermination(self, timeout)
#     199     return self._jsq.awaitTermination(int(timeout * 1000))
#     200 else:
# --> 201     return self._jsq.awaitTermination()
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File /opt/conda/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:
